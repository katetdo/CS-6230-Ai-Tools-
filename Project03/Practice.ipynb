# %%
import matplotlib.pyplot as plt
import numpy as np

test_points = np.linspace(-10,10,100)
line_equation = lambda x_1 : 1/2 * x_1 +1

results = line_equation(test_points)

plt.plot(test_points, results)
plt.show()

# %%
test_points.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 test_points.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'
